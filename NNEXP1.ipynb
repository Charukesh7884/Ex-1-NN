# %%
from google.colab import files

# %%
import pandas as pd
import io
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
#Read the dataset from drive
df = pd.read_csv("dataset_2191_sleep.csv");
print(df)
# Out:
#     body_weight  brain_weight max_life_span gestation_time  predation_index  \
# 0      6654.000        5712.0          38.6            645                3
# 1         1.000           6.6           4.5             42                3
# 2         3.385          44.5            14             60                1
# 3         0.920           5.7             ?             25                5
# 4      2547.000        4603.0            69            624                3
# ..          ...           ...           ...            ...              ...
# 57        2.000          12.3           7.5            200                3
# 58        0.104           2.5           2.3             46                3
# 59        4.190          58.0            24            210                4
# 60        3.500           3.9             3             14                2
# 61        4.050          17.0            13             38                3
#
#     sleep_exposure_index  danger_index total_sleep
# 0                      5             3         3.3
# 1                      1             3         8.3
# 2                      1             1        12.5
# 3                      2             3        16.5
# 4                      5             4         3.9
# ..                   ...           ...         ...
# 57                     1             3         5.4
# 58                     2             2        15.8
# 59                     3             4        10.3
# 60                     1             1        19.4
# 61                     1             1           ?
#
# [62 rows x 8 columns]

# %%
#split the dataset
X = df.iloc[:, :-1].values

y = df.iloc[:, -1].values

print(X)
print(y)
# Out:
# [[6654.0 5712.0 '38.6' '645' 3 5 3]
#  [1.0 6.6 '4.5' '42' 3 1 3]
#  [3.385 44.5 '14' '60' 1 1 1]
#  [0.92 5.7 '?' '25' 5 2 3]
#  [2547.0 4603.0 '69' '624' 3 5 4]
#  [10.55 179.5 '27' '180' 4 4 4]
#  [0.023 0.3 '19' '35' 1 1 1]
#  [160.0 169.0 '30.4' '392' 4 5 4]
#  [3.3 25.6 '28' '63' 1 2 1]
#  [52.16 440.0 '50' '230' 1 1 1]
#  [0.425 6.4 '7' '112' 5 4 4]
#  [465.0 423.0 '30' '281' 5 5 5]
#  [0.55 2.4 '?' '?' 2 1 2]
#  [187.1 419.0 '40' '365' 5 5 5]
#  [0.075 1.2 '3.5' '42' 1 1 1]
#  [3.0 25.0 '50' '28' 2 2 2]
#  [0.785 3.5 '6' '42' 2 2 2]
#  [0.2 5.0 '10.4' '120' 2 2 2]
#  [1.41 17.5 '34' '?' 1 2 1]
#  [60.0 81.0 '7' '?' 1 1 1]
#  [529.0 680.0 '28' '400' 5 5 5]
#  [27.66 115.0 '20' '148' 5 5 5]
#  [0.12 1.0 '3.9' '16' 3 1 2]
#  [207.0 406.0 '39.3' '252' 1 4 1]
#  [85.0 325.0 '41' '310' 1 3 1]
#  [36.33 119.5 '16.2' '63' 1 1 1]
#  [0.101 4.0 '9' '28' 5 1 3]
#  [1.04 5.5 '7.6' '68' 5 3 4]
#  [521.0 655.0 '46' '336' 5 5 5]
#  [100.0 157.0 '22.4' '100' 1 1 1]
#  [35.0 56.0 '16.3' '33' 3 5 4]
#  [0.005 0.14 '2.6' '21.5' 5 2 4]
#  [0.01 0.25 '24' '50' 1 1 1]
#  [62.0 1320.0 '100' '267' 1 1 1]
#  [0.122 3.0 '?' '30' 2 1 1]
#  [1.35 8.1 '?' '45' 3 1 3]
#  [0.023 0.4 '3.2' '19' 4 1 3]
#  [0.048 0.33 '2' '30' 4 1 3]
#  [1.7 6.3 '5' '12' 2 1 1]
#  [3.5 10.8 '6.5' '120' 2 1 1]
#  [250.0 490.0 '23.6' '440' 5 5 5]
#  [0.48 15.5 '12' '140' 2 2 2]
#  [10.0 115.0 '20.2' '170' 4 4 4]
#  [1.62 11.4 '13' '17' 2 1 2]
#  [192.0 180.0 '27' '115' 4 4 4]
#  [2.5 12.1 '18' '31' 5 5 5]
#  [4.288 39.2 '13.7' '63' 2 2 2]
#  [0.28 1.9 '4.7' '21' 3 1 3]
#  [4.235 50.4 '9.8' '52' 1 1 1]
#  [6.8 179.0 '29' '164' 2 3 2]
#  [0.75 12.3 '7' '225' 2 2 2]
#  [3.6 21.0 '6' '225' 3 2 3]
#  [14.83 98.2 '17' '150' 5 5 5]
#  [55.5 175.0 '20' '151' 5 5 5]
#  [1.4 12.5 '12.7' '90' 2 2 2]
#  [0.06 1.0 '3.5' '?' 3 1 2]
#  [0.9 2.6 '4.5' '60' 2 1 2]
#  [2.0 12.3 '7.5' '200' 3 1 3]
#  [0.104 2.5 '2.3' '46' 3 2 2]
#  [4.19 58.0 '24' '210' 4 3 4]
#  [3.5 3.9 '3' '14' 2 1 1]
#  [4.05 17.0 '13' '38' 3 1 1]]
# ['3.3' '8.3' '12.5' '16.5' '3.9' '9.8' '19.7' '6.2' '14.5' '9.7' '12.5'
#  '3.9' '10.3' '3.1' '8.4' '8.6' '10.7' '10.7' '6.1' '18.1' '?' '3.8'
#  '14.4' '12' '6.2' '13' '13.8' '8.2' '2.9' '10.8' '?' '9.1' '19.9' '8'
#  '10.6' '11.2' '13.2' '12.8' '19.4' '17.4' '?' '17' '10.9' '13.7' '8.4'
#  '8.4' '12.5' '13.2' '9.8' '9.6' '6.6' '5.4' '2.6' '3.8' '11' '10.3'
#  '13.3' '5.4' '15.8' '10.3' '19.4' '?']

# %%
#Finding Missing Values
print(df.isnull().sum())
# Out:
# body_weight             0
# brain_weight            0
# max_life_span           0
# gestation_time          0
# predation_index         0
# sleep_exposure_index    0
# danger_index            0
# total_sleep             0
# dtype: int64

# %%
#Handling Missing values
df.fillna(df.select_dtypes(include='number').mean().round(1), inplace=True)
y = df.iloc[:, -1].values

# %%
df.drop(['body_weight','max_life_span','total_sleep'], axis=1, inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   brain_weight          62 non-null     float64
#  1   gestation_time        62 non-null     object
#  2   predation_index       62 non-null     int64
#  3   sleep_exposure_index  62 non-null     int64
#  4   danger_index          62 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.6+ KB

# %%
#Check for Duplicates
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 57    False
# 58    False
# 59    False
# 60    False
# 61    False
# Length: 62, dtype: bool

# %%
#Detect Outliers
print(df['Lead Streams (in millions)'].describe())
# Out:
# count       500.000000
# mean      12215.024000
# std       11806.975799
# min           8.400000
# 25%        6579.300000
# 50%        8831.800000
# 75%       13456.900000
# max      126177.300000
# Name: Lead Streams (in millions), dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# Select only numeric columns
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns

# Scale only numeric columns
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

print(df)
# Out:
#     brain_weight gestation_time  predation_index  sleep_exposure_index  \
# 0       1.000000            645             0.50                  1.00
# 1       0.001131             42             0.50                  0.00
# 2       0.007766             60             0.00                  0.00
# 3       0.000973             25             1.00                  0.25
# 4       0.805843            624             0.50                  1.00
# ..           ...            ...              ...                   ...
# 57      0.002129            200             0.50                  0.00
# 58      0.000413             46             0.50                  0.25
# 59      0.010130            210             0.75                  0.50
# 60      0.000658             14             0.25                  0.00
# 61      0.002952             38             0.50                  0.00
#
#     danger_index
# 0           0.50
# 1           0.50
# 2           0.00
# 3           0.50
# 4           0.75
# ..           ...
# 57          0.50
# 58          0.25
# 59          0.75
# 60          0.00
# 61          0.00
#
# [62 rows x 5 columns]

# %%
#splitting the data for training and testing
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2)

#'test_size = 0.2' means 20% test data and 80% train data
print(X_train)
print(len(X_train))
print(X_test)
print(len(X_test))
# Out:
# [[0.023 0.3 '19' '35' 1 1 1]
#  [3.0 25.0 '50' '28' 2 2 2]
#  [0.005 0.14 '2.6' '21.5' 5 2 4]
#  [4.05 17.0 '13' '38' 3 1 1]
#  [3.5 3.9 '3' '14' 2 1 1]
#  [1.0 6.6 '4.5' '42' 3 1 3]
#  [0.28 1.9 '4.7' '21' 3 1 3]
#  [3.385 44.5 '14' '60' 1 1 1]
#  [0.48 15.5 '12' '140' 2 2 2]
#  [0.122 3.0 '?' '30' 2 1 1]
#  [0.075 1.2 '3.5' '42' 1 1 1]
#  [1.62 11.4 '13' '17' 2 1 2]
#  [14.83 98.2 '17' '150' 5 5 5]
#  [10.55 179.5 '27' '180' 4 4 4]
#  [1.35 8.1 '?' '45' 3 1 3]
#  [187.1 419.0 '40' '365' 5 5 5]
#  [192.0 180.0 '27' '115' 4 4 4]
#  [4.288 39.2 '13.7' '63' 2 2 2]
#  [6.8 179.0 '29' '164' 2 3 2]
#  [1.7 6.3 '5' '12' 2 1 1]
#  [0.9 2.6 '4.5' '60' 2 1 2]
#  [35.0 56.0 '16.3' '33' 3 5 4]
#  [0.75 12.3 '7' '225' 2 2 2]
#  [1.4 12.5 '12.7' '90' 2 2 2]
#  [85.0 325.0 '41' '310' 1 3 1]
#  [3.5 10.8 '6.5' '120' 2 1 1]
#  [55.5 175.0 '20' '151' 5 5 5]
#  [1.41 17.5 '34' '?' 1 2 1]
#  [0.425 6.4 '7' '112' 5 4 4]
#  [0.023 0.4 '3.2' '19' 4 1 3]
#  [62.0 1320.0 '100' '267' 1 1 1]
#  [250.0 490.0 '23.6' '440' 5 5 5]
#  [465.0 423.0 '30' '281' 5 5 5]
#  [0.92 5.7 '?' '25' 5 2 3]
#  [2.0 12.3 '7.5' '200' 3 1 3]
#  [36.33 119.5 '16.2' '63' 1 1 1]
#  [0.06 1.0 '3.5' '?' 3 1 2]
#  [207.0 406.0 '39.3' '252' 1 4 1]
#  [0.048 0.33 '2' '30' 4 1 3]
#  [521.0 655.0 '46' '336' 5 5 5]
#  [3.6 21.0 '6' '225' 3 2 3]
#  [0.785 3.5 '6' '42' 2 2 2]
#  [3.3 25.6 '28' '63' 1 2 1]
#  [52.16 440.0 '50' '230' 1 1 1]
#  [2.5 12.1 '18' '31' 5 5 5]
#  [529.0 680.0 '28' '400' 5 5 5]
#  [0.2 5.0 '10.4' '120' 2 2 2]
#  [0.12 1.0 '3.9' '16' 3 1 2]
#  [100.0 157.0 '22.4' '100' 1 1 1]]
# 49
# [[4.19 58.0 '24' '210' 4 3 4]
#  [160.0 169.0 '30.4' '392' 4 5 4]
#  [0.101 4.0 '9' '28' 5 1 3]
#  [0.104 2.5 '2.3' '46' 3 2 2]
#  [60.0 81.0 '7' '?' 1 1 1]
#  [0.55 2.4 '?' '?' 2 1 2]
#  [10.0 115.0 '20.2' '170' 4 4 4]
#  [6654.0 5712.0 '38.6' '645' 3 5 3]
#  [1.04 5.5 '7.6' '68' 5 3 4]
#  [0.01 0.25 '24' '50' 1 1 1]
#  [27.66 115.0 '20' '148' 5 5 5]
#  [4.235 50.4 '9.8' '52' 1 1 1]
#  [2547.0 4603.0 '69' '624' 3 5 4]]
# 13
